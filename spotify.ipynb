# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('spotify_data_dictionary.csv')
df1=pd.read_csv('spotify_history.csv')

# %%
df
# Out:
#                 Field                                        Description
# 0   spotify_track_uri  Spotify URI that uniquely identifies each trac...
# 1                  ts  Timestamp indicating when the track stopped pl...
# 2            platform             Platform used when streaming the track
# 3           ms_played       Number of milliseconds the stream was played
# 4          track_name                                  Name of the track
# 5         artist_name                                 Name of the artist
# 6          album_name                                  Name of the album
# 7        reason_start                              Why the track started
# 8          reason_end                                Why the track ended
# 9             shuffle  TRUE or FALSE depending on if shuffle mode was...
# 10            skipped  TRUE of FALSE depending on if the user skipped...

# %%
df1.head(50)
# Out:
#          spotify_track_uri                   ts    platform  ms_played  \
# 0   2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1   1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2   487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3   5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4   0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
# 5   50VNvhzyaSplJCKWchN7a8  2013-07-08 03:17:52  web player      63485
# 6   1I4EczxGBcPR3J3KeyqFJP  2013-07-08 03:17:56  web player          0
# 7   5arVt2Wg0zbiWwAOZef2Nl  2013-07-08 03:17:56  web player       1268
# 8   1ixtaZc0Adil3yD1ItPqSl  2013-07-08 03:17:58  web player          0
# 9   2v5mpowLQNFN7NC46l0bJS  2013-07-08 03:19:11  web player          0
# 10  07hII2Rc29q4F2nTE3P1od  2013-07-08 03:20:20  web player      67587
# 11  4kO7mrAPfqIrsKwUOK5BFx  2013-07-08 03:20:36  web player      12846
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149860 entries, 0 to 149859
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   spotify_track_uri  149860 non-null  object
#  1   ts                 149860 non-null  object
#  2   platform           149860 non-null  object
#  3   ms_played          149860 non-null  int64
#  4   track_name         149860 non-null  object
#  5   artist_name        149860 non-null  object
#  6   album_name         149860 non-null  object
#  7   reason_start       149717 non-null  object
#  8   reason_end         149743 non-null  object
#  9   shuffle            149860 non-null  bool
#  10  skipped            149860 non-null  bool
# dtypes: bool(2), int64(1), object(8)
# memory usage: 10.6+ MB

# %%
df1.corr()
# Out:
# C:\Users\Emmanuel Kusi\AppData\Local\Temp\ipykernel_26940\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#            ms_played   shuffle   skipped
# ms_played   1.000000 -0.182784 -0.193644
# shuffle    -0.182784  1.000000  0.024345
# skipped    -0.193644  0.024345  1.000000

# %%
df1.columns
# Out:
# Index(['spotify_track_uri', 'ts', 'platform', 'ms_played', 'track_name',
#        'artist_name', 'album_name', 'reason_start', 'reason_end', 'shuffle',
#        'skipped'],
#       dtype='object')

# %%
df1['platform'].unique()
# Out:
# array(['web player', 'windows', 'android', 'iOS', 'cast to device', 'mac'],
#       dtype=object)

# %%
df1['spotify_track_uri']
# Out:
# 0         2J3n32GeLmMjwuAzyhcSNe
# 1         1oHxIPqJyvAYHy0PVrDU98
# 2         487OPlneJNni3NWC8SYqhW
# 3         5IyblF777jLZj1vGHG2UD3
# 4         0GgAAB0ZMllFhbNc3mAodO
#                    ...
# 149855    4Fz1WWr5o0OrlIcZxcyZtK
# 149856    0qHMhBZqYb99yhX9BHcIkV
# 149857    0HHdujGjOZChTrl8lJWEIq
# 149858    7peh6LUcdNPcMdrSH4JPsM
# 149859    6iGU74CwXuT4XVepjc9Emf
# Name: spotify_track_uri, Length: 149860, dtype: object

# %%
df1['track_name'].value_counts()
# Out:
# Ode To The Mets                                                         207
# In the Blood                                                            181
# Dying Breed                                                             166
# Caution                                                                 164
# 19 Dias y 500 Noches - En Directo                                       148
#                                                                        ...
# Mick Jagger's Introduction Of Rock And Roll Circus - Remastered 2018      1
# Hideout                                                                   1
# Amongst The Waves                                                         1
# One More Year                                                             1
# Cucurrucucu Paloma                                                        1
# Name: track_name, Length: 13839, dtype: int64

# %%
df1['artist_name'].value_counts()
# Out:
# The Beatles                         13621
# The Killers                          6878
# John Mayer                           4855
# Bob Dylan                            3814
# Paul McCartney                       2697
#                                     ...
# Johnny Flynn                            1
# Moriarty                                1
# Daniel Johnston                         1
# Buena Vista Social Club                 1
# Better Oblivion Community Center        1
# Name: artist_name, Length: 4113, dtype: int64

# %%
favs=df1.groupby(['track_name','artist_name','ms_played'])

# %%
favs.head()
# Out:
#              spotify_track_uri                   ts    platform  ms_played  \
# 0       2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1       1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2       487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3       5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4       0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
# ...                        ...                  ...         ...        ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK  2024-12-15 23:06:19     android       1247
# 149856  0qHMhBZqYb99yhX9BHcIkV  2024-12-15 23:06:21     android       1515
# 149857  0HHdujGjOZChTrl8lJWEIq  2024-12-15 23:06:22     android       1283
# 149858  7peh6LUcdNPcMdrSH4JPsM  2024-12-15 23:06:23     android       1306
# 149859  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
#
# ...

# %%
df1['ms_played'].value_counts(ascending=False)
# Out:
# 0         3733
# 23        2413
# 1532       165
# 246000     139
# 243666     137
#           ...
# 165281       1
# 22792        1
# 79166        1
# 112574       1
# 10672        1
# Name: ms_played, Length: 43082, dtype: int64

# %%
df1.loc[df1['ms_played'].idxmax()]
# Out:
# spotify_track_uri    7ERSQrRptZVM7q3VOdM7OL
# ts                      2021-03-04 00:27:48
# platform                            android
# ms_played                           1561125
# track_name            Tubular Bells - Pt. I
# artist_name                   Mike Oldfield
# album_name                    Tubular Bells
# reason_start                        appload
# reason_end                        trackdone
# shuffle                               False
# skipped                               False
# Name: 94634, dtype: object

# %%
# Top 10 artists
top_artists = df1["artist_name"].value_counts().head(10)
plt.barh(top_artists.index, top_artists.values)
plt.title("Most Listened Artists")
plt.show()
